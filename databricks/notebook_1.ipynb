# %% [markdown]
# # Notebook 1

# %%
print("HEllo world")

# %%
# %sql
SELECT "hola"

# %%
_sqldf.show()

# %% [markdown]
# ## **stuff**

# %%
# %run ./setup

# %%
print(book_publisher)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls('/')
display(files)
